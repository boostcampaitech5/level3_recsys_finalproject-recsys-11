# %%
import requests

# %%
# https://developers.google.com/custom-search/v1/introduction?hl=ko
SEARCH_ENGINE_ID = 'e4aedac5a2e134c90'
API_KEY = 'AIzaSyDisofHCPsYgtkUffkC2fFkh0H9tWcJ-mU'

# %%
query = '오늘 날씨'
page = 1
cnt = 10
start = (page - 1) * cnt + 1
# https://developers.google.com/custom-search/docs/xml_results?hl=ko#WebSearch_Request_Format
url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}&start={start}"

# %%
# API request
data = requests.get(url).json()
search_items = data.get('items')

for i, search_item in enumerate(search_items, start=1):
    try:
        long_description = search_item["pagemap"]["metatags"][0]["og:description"]
    except KeyError:
        long_description = "N/A"
    # get the page title
    title = search_item.get("title")
    # page snippet
    snippet = search_item.get("snippet")
    # alternatively, you can get the HTML snippet (bolded keywords)
    html_snippet = search_item.get("htmlSnippet")
    # extract the page url
    link = search_item.get("link")
 
    print(f"#{i+start-1}")
    print('='*40)
    print("title:", title)
    print("description:", snippet)
    print("long description:", long_description)
    print("URL:", link, "\n")
# Out:
# #1
# ...
# title: 기상청 날씨누리: 홈
# description: 오늘 · 시각: 16시 · 날씨: 비 · 기온(체감온도) 27℃(29℃) · 체감온도: 29℃ · 강수량: 1mm · 강수확률: 60% · 바람: 남동풍3m/s · 습도: 85% ...
# long description: 기상청 날씨누리
# URL: https://www.weather.go.kr/
#
# #2
# ...
# title: 네이버 날씨
# description: None
# long description: N/A
# URL: https://weather.naver.com/
#
# #3
# ...
# title: 단기예보 - 기상청 날씨누리
# description: 현재위치의 단기예보의 정보를 비교해서 나타낸 표입니다. 예보요소, 평년(오늘), 어제(04일), 오늘(05일), 내일 ...
# long description: N/A
# URL: https://www.kma.go.kr/w/weather/forecast/short-term.do
#
# #4
# ...
# title: 현재 날씨 - 기상청 날씨누리
# description: 기상실황표로 지점, 날씨, 기온, 강수, 바람, 기압등을 안내한 표입니다. 날씨, 기온(℃), 강수, 바람, 기압(hPa). 지점, 현재일기, 시정 km, 운량
# long description: N/A
# URL: https://www.weather.go.kr/w/weather/now.do
#
# #5
# ...
# title: 홈 - 기상청 날씨누리
# description: 날씨지도 닫기. 초단기강수예측 특보. 어제. 최고/최저 강수. 1시간관측. 날씨/기온 일강수 풍향/풍속. 현재날씨. 강수유무/기온 1시간강수량/풍향/풍속.
# long description: 기상청 날씨누리
# URL: http://www.weather.go.kr/w/index.do
#
# #6
# ...
# title: App Store에서 제공하는 오늘날씨 - 미세먼지와 기상청 날씨
# ...

# %%
response = requests.get(url)
print(response.text)
# Out:
# {
#   "kind": "customsearch#search",
#   "url": {
#     "type": "application/json",
#     "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#   },
#   "queries": {
#     "request": [
#       {
#         "title": "Google Custom Search - 메머드 커피",
#         "totalResults": "316000",
#         "searchTerms": "메머드 커피",
#         "count": 10,
# ...
